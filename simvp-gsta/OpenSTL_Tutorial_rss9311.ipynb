# %% [markdown]
# <a href="https://colab.research.google.com/github/rss9311/simvpOpenStl/blob/master/OpenSTL_Tutorial_rss9311.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # OpenSTL Tutorial

# %% [markdown]
# In this notebook, we will provide a comprehensive guide on how to use OpenSTL for your own project.
#
# Firstly, we will process video data into `.npy` format for easier storage and access. Next, we will demonstrate how to utilize custom data within OpenSTL. Subsequently, we will use OpenSTL to train and evaluate models. Finally, we will visualize predicted frames and generate `.gif` images or videos.
#
# - [0. Setup the environment](#0-setup-the-environment)
#
# - [1. Preprocess your data](#1-process-your-data)
#     - [1.1 Save the dataset](#11-save-the-dataset)
#     - [1.2 Load the dataset and visualize an example](#12-load-the-dataset-and-visualize-an-example)
#
# - [2. Utilize cumtom data](#2-utilize-cumtom-data)
#     - [2.1 Define the dataset](#21-define-the-dataset)
#     - [2.2 Get the dataloaders](#22-get-the-dataloaders)
#
# - [3. Train and evaluate](#3-train-and-evaluate)
#     - [3.1 Define the custom configs](#31-define-the-custom-configs)
#     - [3.2 Setup the experiment](#32-setup-the-experiment)
#     - [3.3 Start training and evaluation](#33)
#
# - [4. Visualization](#4-visualization)
#     - [4.1 Visualize in a line](#41-visualize-in-a-line)
#     - [4.2 Generate a GIF](#42-generate-a-gif)
#
# Here we go!

# %% [markdown]
# ## 0. Setup the environment

# %%
# !git clone https://github.com/chengtan9907/OpenSTL
# Out:
# Cloning into 'OpenSTL'...
# remote: Enumerating objects: 2192, done.
# remote: Counting objects: 100% (677/677), done.
# remote: Compressing objects: 100% (140/140), done.
# remote: Total 2192 (delta 608), reused 539 (delta 537), pack-reused 1515
# Receiving objects: 100% (2192/2192), 2.10 MiB | 2.63 MiB/s, done.
# Resolving deltas: 100% (1620/1620), done.

# %%
import os
os.chdir('/content/OpenSTL')

# !python setup.py develop
# Out:
# running install
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer, pypa/build or
#         other standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:66: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
#         Instead, use pypa/build, pypa/installer, pypa/build or
#         other standards-based tools.
#
#         See https://github.com/pypa/setuptools/issues/917 for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# running bdist_egg
# running egg_info
# creating OpenSTL.egg-info
# writing OpenSTL.egg-info/PKG-INFO
# writing dependency_links to OpenSTL.egg-info/dependency_links.txt
# writing requirements to OpenSTL.egg-info/requires.txt
# writing top-level names to OpenSTL.egg-info/top_level.txt
# writing manifest file 'OpenSTL.egg-info/SOURCES.txt'
# reading manifest file 'OpenSTL.egg-info/SOURCES.txt'
# adding license file 'LICENSE'
# writing manifest file 'OpenSTL.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build
# creating build/lib
# creating build/lib/openstl
# copying openstl/version.py -> build/lib/openstl
# copying openstl/__init__.py -> build/lib/openstl
# creating build/lib/openstl/models
# copying openstl/models/mim_model.py -> build/lib/openstl/models
# copying openstl/models/simvp_model.py -> build/lib/openstl/models
# copying openstl/models/predrnnpp_model.py -> build/lib/openstl/models
# copying openstl/models/prednet_model.py -> build/lib/openstl/models
# copying openstl/models/predrnnv2_model.py -> build/lib/openstl/models
# copying openstl/models/predrnn_model.py -> build/lib/openstl/models
# copying openstl/models/mau_model.py -> build/lib/openstl/models
# copying openstl/models/phydnet_model.py -> build/lib/openstl/models
# copying openstl/models/e3dlstm_model.py -> build/lib/openstl/models
# copying openstl/models/convlstm_model.py -> build/lib/openstl/models
# copying openstl/models/__init__.py -> build/lib/openstl/models
# copying openstl/models/crevnet_model.py -> build/lib/openstl/models
# copying openstl/models/dmvfn_model.py -> build/lib/openstl/models
# creating build/lib/openstl/api
# copying openstl/api/train.py -> build/lib/openstl/api
# copying openstl/api/__init__.py -> build/lib/openstl/api
# creating build/lib/openstl/datasets
# copying openstl/datasets/dataloader_kinetics.py -> build/lib/openstl/datasets
# copying openstl/datasets/dataloader_bair.py -> build/lib/openstl/datasets
# copying openstl/datasets/dataloader.py -> build/lib/openstl/datasets
# copying openstl/datasets/dataloader_kth.py -> build/lib/openstl/datasets
# copying openstl/datasets/utils.py -> build/lib/openstl/datasets
# copying openstl/datasets/dataset_constant.py -> build/lib/openstl/datasets
# copying openstl/datasets/dataloader_moving_mnist.py -> build/lib/openstl/datasets
# copying openstl/datasets/dataloader_weather.py -> build/lib/openstl/datasets
# copying openstl/datasets/dataloader_kitticaltech.py -> build/lib/openstl/datasets
# copying openstl/datasets/dataloader_noisy_moving_mnist.py -> build/lib/openstl/datasets
# copying openstl/datasets/dataloader_human.py -> build/lib/openstl/datasets
# copying openstl/datasets/__init__.py -> build/lib/openstl/datasets
# copying openstl/datasets/dataloader_taxibj.py -> build/lib/openstl/datasets
# creating build/lib/openstl/methods
# copying openstl/methods/base_method.py -> build/lib/openstl/methods
# copying openstl/methods/mau.py -> build/lib/openstl/methods
# copying openstl/methods/dmvfn.py -> build/lib/openstl/methods
# copying openstl/methods/phydnet.py -> build/lib/openstl/methods
# copying openstl/methods/predrnnpp.py -> build/lib/openstl/methods
# copying openstl/methods/simvp.py -> build/lib/openstl/methods
# copying openstl/methods/crevnet.py -> build/lib/openstl/methods
# copying openstl/methods/prednet.py -> build/lib/openstl/methods
# copying openstl/methods/tau.py -> build/lib/openstl/methods
# copying openstl/methods/mim.py -> build/lib/openstl/methods
# copying openstl/methods/__init__.py -> build/lib/openstl/methods
# copying openstl/methods/convlstm.py -> build/lib/openstl/methods
# copying openstl/methods/predrnnv2.py -> build/lib/openstl/methods
# copying openstl/methods/predrnn.py -> build/lib/openstl/methods
# copying openstl/methods/e3dlstm.py -> build/lib/openstl/methods
# creating build/lib/openstl/modules
# copying openstl/modules/dmvfn_modules.py -> build/lib/openstl/modules
# copying openstl/modules/simvp_modules.py -> build/lib/openstl/modules
# copying openstl/modules/predrnn_modules.py -> build/lib/openstl/modules
# copying openstl/modules/mau_modules.py -> build/lib/openstl/modules
# copying openstl/modules/predrnnv2_modules.py -> build/lib/openstl/modules
# copying openstl/modules/e3dlstm_modules.py -> build/lib/openstl/modules
# copying openstl/modules/predrnnpp_modules.py -> build/lib/openstl/modules
# copying openstl/modules/convlstm_modules.py -> build/lib/openstl/modules
# copying openstl/modules/prednet_modules.py -> build/lib/openstl/modules
# copying openstl/modules/__init__.py -> build/lib/openstl/modules
# copying openstl/modules/crevnet_modules.py -> build/lib/openstl/modules
# copying openstl/modules/phydnet_modules.py -> build/lib/openstl/modules
# copying openstl/modules/mim_modules.py -> build/lib/openstl/modules
# creating build/lib/openstl/core
# copying openstl/core/optim_constant.py -> build/lib/openstl/core
# copying openstl/core/optim_scheduler.py -> build/lib/openstl/core
# copying openstl/core/recorder.py -> build/lib/openstl/core
# copying openstl/core/ema_hook.py -> build/lib/openstl/core
# copying openstl/core/__init__.py -> build/lib/openstl/core
# copying openstl/core/hooks.py -> build/lib/openstl/core
# copying openstl/core/metrics.py -> build/lib/openstl/core
# creating build/lib/openstl/utils
# copying openstl/utils/dmvfn_utils.py -> build/lib/openstl/utils
# copying openstl/utils/prednet_utils.py -> build/lib/openstl/utils
# copying openstl/utils/collect.py -> build/lib/openstl/utils
# copying openstl/utils/config_utils.py -> build/lib/openstl/utils
# copying openstl/utils/predrnn_utils.py -> build/lib/openstl/utils
# copying openstl/utils/visualization.py -> build/lib/openstl/utils
# copying openstl/utils/progressbar.py -> build/lib/openstl/utils
# copying openstl/utils/parser.py -> build/lib/openstl/utils
# copying openstl/utils/main_utils.py -> build/lib/openstl/utils
# copying openstl/utils/__init__.py -> build/lib/openstl/utils
# creating build/lib/openstl/datasets/pipelines
# copying openstl/datasets/pipelines/transforms.py -> build/lib/openstl/datasets/pipelines
# copying openstl/datasets/pipelines/__init__.py -> build/lib/openstl/datasets/pipelines
# creating build/lib/openstl/modules/layers
# copying openstl/modules/layers/van.py -> build/lib/openstl/modules/layers
# copying openstl/modules/layers/hornet.py -> build/lib/openstl/modules/layers
# copying openstl/modules/layers/uniformer.py -> build/lib/openstl/modules/layers
# copying openstl/modules/layers/poolformer.py -> build/lib/openstl/modules/layers
# copying openstl/modules/layers/__init__.py -> build/lib/openstl/modules/layers
# copying openstl/modules/layers/moganet.py -> build/lib/openstl/modules/layers
# creating build/bdist.linux-x86_64
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/openstl
# creating build/bdist.linux-x86_64/egg/openstl/models
# copying build/lib/openstl/models/mim_model.py -> build/bdist.linux-x86_64/egg/openstl/models
# copying build/lib/openstl/models/simvp_model.py -> build/bdist.linux-x86_64/egg/openstl/models
# copying build/lib/openstl/models/predrnnpp_model.py -> build/bdist.linux-x86_64/egg/openstl/models
# copying build/lib/openstl/models/prednet_model.py -> build/bdist.linux-x86_64/egg/openstl/models
# copying build/lib/openstl/models/predrnnv2_model.py -> build/bdist.linux-x86_64/egg/openstl/models
# copying build/lib/openstl/models/predrnn_model.py -> build/bdist.linux-x86_64/egg/openstl/models
# copying build/lib/openstl/models/mau_model.py -> build/bdist.linux-x86_64/egg/openstl/models
# copying build/lib/openstl/models/phydnet_model.py -> build/bdist.linux-x86_64/egg/openstl/models
# copying build/lib/openstl/models/e3dlstm_model.py -> build/bdist.linux-x86_64/egg/openstl/models
# copying build/lib/openstl/models/convlstm_model.py -> build/bdist.linux-x86_64/egg/openstl/models
# copying build/lib/openstl/models/__init__.py -> build/bdist.linux-x86_64/egg/openstl/models
# copying build/lib/openstl/models/crevnet_model.py -> build/bdist.linux-x86_64/egg/openstl/models
# copying build/lib/openstl/models/dmvfn_model.py -> build/bdist.linux-x86_64/egg/openstl/models
# creating build/bdist.linux-x86_64/egg/openstl/api
# copying build/lib/openstl/api/train.py -> build/bdist.linux-x86_64/egg/openstl/api
# copying build/lib/openstl/api/__init__.py -> build/bdist.linux-x86_64/egg/openstl/api
# copying build/lib/openstl/version.py -> build/bdist.linux-x86_64/egg/openstl
# creating build/bdist.linux-x86_64/egg/openstl/datasets
# copying build/lib/openstl/datasets/dataloader_kinetics.py -> build/bdist.linux-x86_64/egg/openstl/datasets
# creating build/bdist.linux-x86_64/egg/openstl/datasets/pipelines
# copying build/lib/openstl/datasets/pipelines/transforms.py -> build/bdist.linux-x86_64/egg/openstl/datasets/pipelines
# copying build/lib/openstl/datasets/pipelines/__init__.py -> build/bdist.linux-x86_64/egg/openstl/datasets/pipelines
# copying build/lib/openstl/datasets/dataloader_bair.py -> build/bdist.linux-x86_64/egg/openstl/datasets
# copying build/lib/openstl/datasets/dataloader.py -> build/bdist.linux-x86_64/egg/openstl/datasets
# copying build/lib/openstl/datasets/dataloader_kth.py -> build/bdist.linux-x86_64/egg/openstl/datasets
# copying build/lib/openstl/datasets/utils.py -> build/bdist.linux-x86_64/egg/openstl/datasets
# copying build/lib/openstl/datasets/dataset_constant.py -> build/bdist.linux-x86_64/egg/openstl/datasets
# copying build/lib/openstl/datasets/dataloader_moving_mnist.py -> build/bdist.linux-x86_64/egg/openstl/datasets
# copying build/lib/openstl/datasets/dataloader_weather.py -> build/bdist.linux-x86_64/egg/openstl/datasets
# copying build/lib/openstl/datasets/dataloader_kitticaltech.py -> build/bdist.linux-x86_64/egg/openstl/datasets
# copying build/lib/openstl/datasets/dataloader_noisy_moving_mnist.py -> build/bdist.linux-x86_64/egg/openstl/datasets
# copying build/lib/openstl/datasets/dataloader_human.py -> build/bdist.linux-x86_64/egg/openstl/datasets
# copying build/lib/openstl/datasets/__init__.py -> build/bdist.linux-x86_64/egg/openstl/datasets
# copying build/lib/openstl/datasets/dataloader_taxibj.py -> build/bdist.linux-x86_64/egg/openstl/datasets
# creating build/bdist.linux-x86_64/egg/openstl/methods
# copying build/lib/openstl/methods/base_method.py -> build/bdist.linux-x86_64/egg/openstl/methods
# copying build/lib/openstl/methods/mau.py -> build/bdist.linux-x86_64/egg/openstl/methods
# copying build/lib/openstl/methods/dmvfn.py -> build/bdist.linux-x86_64/egg/openstl/methods
# copying build/lib/openstl/methods/phydnet.py -> build/bdist.linux-x86_64/egg/openstl/methods
# copying build/lib/openstl/methods/predrnnpp.py -> build/bdist.linux-x86_64/egg/openstl/methods
# copying build/lib/openstl/methods/simvp.py -> build/bdist.linux-x86_64/egg/openstl/methods
# copying build/lib/openstl/methods/crevnet.py -> build/bdist.linux-x86_64/egg/openstl/methods
# copying build/lib/openstl/methods/prednet.py -> build/bdist.linux-x86_64/egg/openstl/methods
# copying build/lib/openstl/methods/tau.py -> build/bdist.linux-x86_64/egg/openstl/methods
# copying build/lib/openstl/methods/mim.py -> build/bdist.linux-x86_64/egg/openstl/methods
# copying build/lib/openstl/methods/__init__.py -> build/bdist.linux-x86_64/egg/openstl/methods
# copying build/lib/openstl/methods/convlstm.py -> build/bdist.linux-x86_64/egg/openstl/methods
# copying build/lib/openstl/methods/predrnnv2.py -> build/bdist.linux-x86_64/egg/openstl/methods
# copying build/lib/openstl/methods/predrnn.py -> build/bdist.linux-x86_64/egg/openstl/methods
# copying build/lib/openstl/methods/e3dlstm.py -> build/bdist.linux-x86_64/egg/openstl/methods
# creating build/bdist.linux-x86_64/egg/openstl/modules
# copying build/lib/openstl/modules/dmvfn_modules.py -> build/bdist.linux-x86_64/egg/openstl/modules
# copying build/lib/openstl/modules/simvp_modules.py -> build/bdist.linux-x86_64/egg/openstl/modules
# copying build/lib/openstl/modules/predrnn_modules.py -> build/bdist.linux-x86_64/egg/openstl/modules
# copying build/lib/openstl/modules/mau_modules.py -> build/bdist.linux-x86_64/egg/openstl/modules
# copying build/lib/openstl/modules/predrnnv2_modules.py -> build/bdist.linux-x86_64/egg/openstl/modules
# creating build/bdist.linux-x86_64/egg/openstl/modules/layers
# copying build/lib/openstl/modules/layers/van.py -> build/bdist.linux-x86_64/egg/openstl/modules/layers
# copying build/lib/openstl/modules/layers/hornet.py -> build/bdist.linux-x86_64/egg/openstl/modules/layers
# copying build/lib/openstl/modules/layers/uniformer.py -> build/bdist.linux-x86_64/egg/openstl/modules/layers
# copying build/lib/openstl/modules/layers/poolformer.py -> build/bdist.linux-x86_64/egg/openstl/modules/layers
# copying build/lib/openstl/modules/layers/__init__.py -> build/bdist.linux-x86_64/egg/openstl/modules/layers
# copying build/lib/openstl/modules/layers/moganet.py -> build/bdist.linux-x86_64/egg/openstl/modules/layers
# copying build/lib/openstl/modules/e3dlstm_modules.py -> build/bdist.linux-x86_64/egg/openstl/modules
# copying build/lib/openstl/modules/predrnnpp_modules.py -> build/bdist.linux-x86_64/egg/openstl/modules
# copying build/lib/openstl/modules/convlstm_modules.py -> build/bdist.linux-x86_64/egg/openstl/modules
# copying build/lib/openstl/modules/prednet_modules.py -> build/bdist.linux-x86_64/egg/openstl/modules
# copying build/lib/openstl/modules/__init__.py -> build/bdist.linux-x86_64/egg/openstl/modules
# copying build/lib/openstl/modules/crevnet_modules.py -> build/bdist.linux-x86_64/egg/openstl/modules
# copying build/lib/openstl/modules/phydnet_modules.py -> build/bdist.linux-x86_64/egg/openstl/modules
# copying build/lib/openstl/modules/mim_modules.py -> build/bdist.linux-x86_64/egg/openstl/modules
# copying build/lib/openstl/__init__.py -> build/bdist.linux-x86_64/egg/openstl
# creating build/bdist.linux-x86_64/egg/openstl/core
# copying build/lib/openstl/core/optim_constant.py -> build/bdist.linux-x86_64/egg/openstl/core
# copying build/lib/openstl/core/optim_scheduler.py -> build/bdist.linux-x86_64/egg/openstl/core
# copying build/lib/openstl/core/recorder.py -> build/bdist.linux-x86_64/egg/openstl/core
# copying build/lib/openstl/core/ema_hook.py -> build/bdist.linux-x86_64/egg/openstl/core
# copying build/lib/openstl/core/__init__.py -> build/bdist.linux-x86_64/egg/openstl/core
# copying build/lib/openstl/core/hooks.py -> build/bdist.linux-x86_64/egg/openstl/core
# copying build/lib/openstl/core/metrics.py -> build/bdist.linux-x86_64/egg/openstl/core
# creating build/bdist.linux-x86_64/egg/openstl/utils
# copying build/lib/openstl/utils/dmvfn_utils.py -> build/bdist.linux-x86_64/egg/openstl/utils
# copying build/lib/openstl/utils/prednet_utils.py -> build/bdist.linux-x86_64/egg/openstl/utils
# copying build/lib/openstl/utils/collect.py -> build/bdist.linux-x86_64/egg/openstl/utils
# copying build/lib/openstl/utils/config_utils.py -> build/bdist.linux-x86_64/egg/openstl/utils
# copying build/lib/openstl/utils/predrnn_utils.py -> build/bdist.linux-x86_64/egg/openstl/utils
# copying build/lib/openstl/utils/visualization.py -> build/bdist.linux-x86_64/egg/openstl/utils
# copying build/lib/openstl/utils/progressbar.py -> build/bdist.linux-x86_64/egg/openstl/utils
# copying build/lib/openstl/utils/parser.py -> build/bdist.linux-x86_64/egg/openstl/utils
# copying build/lib/openstl/utils/main_utils.py -> build/bdist.linux-x86_64/egg/openstl/utils
# copying build/lib/openstl/utils/__init__.py -> build/bdist.linux-x86_64/egg/openstl/utils
# byte-compiling build/bdist.linux-x86_64/egg/openstl/models/mim_model.py to mim_model.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openstl/models/simvp_model.py to simvp_model.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openstl/models/predrnnpp_model.py to predrnnpp_model.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openstl/models/prednet_model.py to prednet_model.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openstl/models/predrnnv2_model.py to predrnnv2_model.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openstl/models/predrnn_model.py to predrnn_model.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openstl/models/mau_model.py to mau_model.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openstl/models/phydnet_model.py to phydnet_model.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openstl/models/e3dlstm_model.py to e3dlstm_model.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openstl/models/convlstm_model.py to convlstm_model.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openstl/models/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openstl/models/crevnet_model.py to crevnet_model.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openstl/models/dmvfn_model.py to dmvfn_model.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openstl/api/train.py to train.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openstl/api/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openstl/version.py to version.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openstl/datasets/dataloader_kinetics.py to dataloader_kinetics.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openstl/datasets/pipelines/transforms.py to transforms.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openstl/datasets/pipelines/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openstl/datasets/dataloader_bair.py to dataloader_bair.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openstl/datasets/dataloader.py to dataloader.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openstl/datasets/dataloader_kth.py to dataloader_kth.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openstl/datasets/utils.py to utils.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openstl/datasets/dataset_constant.py to dataset_constant.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openstl/datasets/dataloader_moving_mnist.py to dataloader_moving_mnist.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openstl/datasets/dataloader_weather.py to dataloader_weather.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openstl/datasets/dataloader_kitticaltech.py to dataloader_kitticaltech.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openstl/datasets/dataloader_noisy_moving_mnist.py to dataloader_noisy_moving_mnist.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openstl/datasets/dataloader_human.py to dataloader_human.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openstl/datasets/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openstl/datasets/dataloader_taxibj.py to dataloader_taxibj.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openstl/methods/base_method.py to base_method.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openstl/methods/mau.py to mau.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openstl/methods/dmvfn.py to dmvfn.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openstl/methods/phydnet.py to phydnet.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openstl/methods/predrnnpp.py to predrnnpp.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openstl/methods/simvp.py to simvp.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openstl/methods/crevnet.py to crevnet.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openstl/methods/prednet.py to prednet.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openstl/methods/tau.py to tau.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openstl/methods/mim.py to mim.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openstl/methods/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openstl/methods/convlstm.py to convlstm.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openstl/methods/predrnnv2.py to predrnnv2.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openstl/methods/predrnn.py to predrnn.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openstl/methods/e3dlstm.py to e3dlstm.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openstl/modules/dmvfn_modules.py to dmvfn_modules.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openstl/modules/simvp_modules.py to simvp_modules.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openstl/modules/predrnn_modules.py to predrnn_modules.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openstl/modules/mau_modules.py to mau_modules.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openstl/modules/predrnnv2_modules.py to predrnnv2_modules.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openstl/modules/layers/van.py to van.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openstl/modules/layers/hornet.py to hornet.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openstl/modules/layers/uniformer.py to uniformer.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openstl/modules/layers/poolformer.py to poolformer.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openstl/modules/layers/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openstl/modules/layers/moganet.py to moganet.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openstl/modules/e3dlstm_modules.py to e3dlstm_modules.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openstl/modules/predrnnpp_modules.py to predrnnpp_modules.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openstl/modules/convlstm_modules.py to convlstm_modules.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openstl/modules/prednet_modules.py to prednet_modules.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openstl/modules/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openstl/modules/crevnet_modules.py to crevnet_modules.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openstl/modules/phydnet_modules.py to phydnet_modules.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openstl/modules/mim_modules.py to mim_modules.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openstl/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openstl/core/optim_constant.py to optim_constant.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openstl/core/optim_scheduler.py to optim_scheduler.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openstl/core/recorder.py to recorder.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openstl/core/ema_hook.py to ema_hook.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openstl/core/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openstl/core/hooks.py to hooks.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openstl/core/metrics.py to metrics.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openstl/utils/dmvfn_utils.py to dmvfn_utils.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openstl/utils/prednet_utils.py to prednet_utils.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openstl/utils/collect.py to collect.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openstl/utils/config_utils.py to config_utils.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openstl/utils/predrnn_utils.py to predrnn_utils.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openstl/utils/visualization.py to visualization.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openstl/utils/progressbar.py to progressbar.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openstl/utils/parser.py to parser.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openstl/utils/main_utils.py to main_utils.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openstl/utils/__init__.py to __init__.cpython-310.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying OpenSTL.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying OpenSTL.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying OpenSTL.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying OpenSTL.egg-info/not-zip-safe -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying OpenSTL.egg-info/requires.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying OpenSTL.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# creating dist
# creating 'dist/OpenSTL-0.3.0-py3.10.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing OpenSTL-0.3.0-py3.10.egg
# creating /usr/local/lib/python3.10/dist-packages/OpenSTL-0.3.0-py3.10.egg
# Extracting OpenSTL-0.3.0-py3.10.egg to /usr/local/lib/python3.10/dist-packages
# Adding OpenSTL 0.3.0 to easy-install.pth file
#
# Installed /usr/local/lib/python3.10/dist-packages/OpenSTL-0.3.0-py3.10.egg
# Processing dependencies for OpenSTL==0.3.0
# Searching for xarray==0.19.0
# Reading https://pypi.org/simple/xarray/
# Downloading https://files.pythonhosted.org/packages/1a/2f/db5c0a3e98febe036a6526fec1eb0218f95917f45fecfbae83198370050e/xarray-0.19.0-py3-none-any.whl#sha256=da0f0d7719b5ee95143a34804e3afb82cb8abbe5c10f9750a9dbed156ad30f00
# Best match: xarray 0.19.0
# Processing xarray-0.19.0-py3-none-any.whl
# Installing xarray-0.19.0-py3-none-any.whl to /usr/local/lib/python3.10/dist-packages
# Adding xarray 0.19.0 to easy-install.pth file
#
# Installed /usr/local/lib/python3.10/dist-packages/xarray-0.19.0-py3.10.egg
# Searching for timm<=0.6.11,>=0.5.4
# Reading https://pypi.org/simple/timm/
# Downloading https://files.pythonhosted.org/packages/19/99/504af0c961e6b6a9494447b3d83d72b79969e9ac17b89394ae343583fb0c/timm-0.6.11-py3-none-any.whl#sha256=8a10e536ecc7caf32a7e42a612a1ae561a1e0d3f1aa836905855f8aff2efa644
# Best match: timm 0.6.11
# Processing timm-0.6.11-py3-none-any.whl
# Installing timm-0.6.11-py3-none-any.whl to /usr/local/lib/python3.10/dist-packages
# Adding timm 0.6.11 to easy-install.pth file
#
# Installed /usr/local/lib/python3.10/dist-packages/timm-0.6.11-py3.10.egg
# Searching for netcdf4
# Reading https://pypi.org/simple/netcdf4/
# Downloading https://files.pythonhosted.org/packages/aa/5a/3bcfa7eb0101c7f64cf86616b3613548a45272906f22b45940934016c597/netCDF4-1.6.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl#sha256=3aaceea2097d292bad398d9f9b4fe403efa7b1568fcfa6faba9b67b1630027f9
# Best match: netCDF4 1.6.5
# Processing netCDF4-1.6.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# Installing netCDF4-1.6.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl to /usr/local/lib/python3.10/dist-packages
# Adding netCDF4 1.6.5 to easy-install.pth file
# Installing nc3tonc4 script to /usr/local/bin
# Installing nc4tonc3 script to /usr/local/bin
# Installing ncinfo script to /usr/local/bin
#
# Installed /usr/local/lib/python3.10/dist-packages/netCDF4-1.6.5-py3.10-linux-x86_64.egg
# Searching for nni
# Reading https://pypi.org/simple/nni/
# Downloading https://files.pythonhosted.org/packages/0b/ed/7a061494753317e0943be1685a4690d05e2e610e5b19aa2823547b584950/nni-3.0-py3-none-manylinux1_x86_64.whl#sha256=176456f8275c096655b6f178dc0589a7642afbb37ecbcce7afe6ad9949592088
# Best match: nni 3.0
# Processing nni-3.0-py3-none-manylinux1_x86_64.whl
# Installing nni-3.0-py3-none-manylinux1_x86_64.whl to /usr/local/lib/python3.10/dist-packages
# Adding nni 3.0 to easy-install.pth file
# Installing nnictl script to /usr/local/bin
#
# Installed /usr/local/lib/python3.10/dist-packages/nni-3.0-py3.10-linux-x86_64.egg
# Searching for lpips
# Reading https://pypi.org/simple/lpips/
# Downloading https://files.pythonhosted.org/packages/9b/13/1df50c7925d9d2746702719f40e864f51ed66f307b20ad32392f1ad2bb87/lpips-0.1.4-py3-none-any.whl#sha256=fd537af5828b69d2e6ffc0a397bd506dbc28ca183543617690844c08e102ec5e
# Best match: lpips 0.1.4
# Processing lpips-0.1.4-py3-none-any.whl
# Installing lpips-0.1.4-py3-none-any.whl to /usr/local/lib/python3.10/dist-packages
# Adding lpips 0.1.4 to easy-install.pth file
#
# Installed /usr/local/lib/python3.10/dist-packages/lpips-0.1.4-py3.10.egg
# Searching for hickle
# Reading https://pypi.org/simple/hickle/
# Downloading https://files.pythonhosted.org/packages/a0/fc/f91e9b1f6f5581b09c91339832a03b4e63444eb1a3565c9d5bad4abaebdd/hickle-5.0.2-py3-none-any.whl#sha256=a05f88fe7a4954131ba4dcd6f4701e800c9cb4e45b3d2f50a40403f18b73024d
# Best match: hickle 5.0.2
# Processing hickle-5.0.2-py3-none-any.whl
# Installing hickle-5.0.2-py3-none-any.whl to /usr/local/lib/python3.10/dist-packages
# Adding hickle 5.0.2 to easy-install.pth file
#
# Installed /usr/local/lib/python3.10/dist-packages/hickle-5.0.2-py3.10.egg
# Searching for fvcore
# Reading https://pypi.org/simple/fvcore/
# Downloading https://files.pythonhosted.org/packages/a5/93/d056a9c4efc6c79ba7b5159cc66bb436db93d2cc46dca18ed65c59cc8e4e/fvcore-0.1.5.post20221221.tar.gz#sha256=f2fb0bb90572ae651c11c78e20493ed19b2240550a7e4bbb2d6de87bdd037860
# Best match: fvcore 0.1.5.post20221221
# Processing fvcore-0.1.5.post20221221.tar.gz
# Writing /tmp/easy_install-4d10j17m/fvcore-0.1.5.post20221221/setup.cfg
# Running fvcore-0.1.5.post20221221/setup.py -q bdist_egg --dist-dir /tmp/easy_install-4d10j17m/fvcore-0.1.5.post20221221/egg-dist-tmp-itdln0_x
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer, pypa/build or
#         other standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# zip_safe flag not set; analyzing archive contents...
# Adding fvcore 0.1.5.post20221221 to easy-install.pth file
#
# Installed /usr/local/lib/python3.10/dist-packages/fvcore-0.1.5.post20221221-py3.10.egg
# Searching for decord
# Reading https://pypi.org/simple/decord/
# Downloading https://files.pythonhosted.org/packages/11/79/936af42edf90a7bd4e41a6cac89c913d4b47fa48a26b042d5129a9242ee3/decord-0.6.0-py3-none-manylinux2010_x86_64.whl#sha256=51997f20be8958e23b7c4061ba45d0efcd86bffd5fe81c695d0befee0d442976
# Best match: decord 0.6.0
# Processing decord-0.6.0-py3-none-manylinux2010_x86_64.whl
# Installing decord-0.6.0-py3-none-manylinux2010_x86_64.whl to /usr/local/lib/python3.10/dist-packages
# Adding decord 0.6.0 to easy-install.pth file
#
# Installed /usr/local/lib/python3.10/dist-packages/decord-0.6.0-py3.10-linux-x86_64.egg
# Searching for cftime
# Reading https://pypi.org/simple/cftime/
# Downloading https://files.pythonhosted.org/packages/fd/c6/03abb5b3e66ca8914b7a4f17ceca72a9b773f11530e973882695bcf2ee5e/cftime-1.6.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl#sha256=f9878bfd8c1c3f24184ecbd528f739ba46ebaceaf1c8a24d348d7befb117a285
# Best match: cftime 1.6.3
# Processing cftime-1.6.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# Installing cftime-1.6.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl to /usr/local/lib/python3.10/dist-packages
# Adding cftime 1.6.3 to easy-install.pth file
#
# Installed /usr/local/lib/python3.10/dist-packages/cftime-1.6.3-py3.10-linux-x86_64.egg
# Searching for websockets>=10.1
# Reading https://pypi.org/simple/websockets/
# Downloading https://files.pythonhosted.org/packages/9a/12/c7a7504f5bf74d6ee0533f6fc7d30d8f4b79420ab179d1df2484b07602eb/websockets-12.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl#sha256=6350b14a40c95ddd53e775dbdbbbc59b124a5c8ecd6fbb09c2e52029f7a9f480
# Best match: websockets 12.0
# Processing websockets-12.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# Installing websockets-12.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl to /usr/local/lib/python3.10/dist-packages
# Adding websockets 12.0 to easy-install.pth file
#
# Installed /usr/local/lib/python3.10/dist-packages/websockets-12.0-py3.10-linux-x86_64.egg
# Searching for typing-extensions>=4.7.0
# Reading https://pypi.org/simple/typing-extensions/
# Downloading https://files.pythonhosted.org/packages/24/21/7d397a4b7934ff4028987914ac1044d3b7d52712f30e2ac7a2ae5bc86dd0/typing_extensions-4.8.0-py3-none-any.whl#sha256=8f92fc8806f9a6b641eaa5318da32b44d401efaac0f6678c9bc448ba3605faa0
# Best match: typing-extensions 4.8.0
# Processing typing_extensions-4.8.0-py3-none-any.whl
# Installing typing_extensions-4.8.0-py3-none-any.whl to /usr/local/lib/python3.10/dist-packages
# Adding typing-extensions 4.8.0 to easy-install.pth file
#
# Installed /usr/local/lib/python3.10/dist-packages/typing_extensions-4.8.0-py3.10.egg
# Searching for typeguard<4.1.3,>=3.0.0
# Reading https://pypi.org/simple/typeguard/
# Downloading https://files.pythonhosted.org/packages/bb/bd/dc7da80c95c920ee2b575e64901b5962ca4a1271b5f3cf6c27242aa0aafc/typeguard-4.1.2-py3-none-any.whl#sha256=e00775920d4c91e93a0db0ed473ecda9cfaca578aed3ce0ed3ba7f3cc38eab9c
# Best match: typeguard 4.1.2
# Processing typeguard-4.1.2-py3-none-any.whl
# Installing typeguard-4.1.2-py3-none-any.whl to /usr/local/lib/python3.10/dist-packages
# Adding typeguard 4.1.2 to easy-install.pth file
#
# Installed /usr/local/lib/python3.10/dist-packages/typeguard-4.1.2-py3.10.egg
# Searching for schema
# Reading https://pypi.org/simple/schema/
# Downloading https://files.pythonhosted.org/packages/0d/93/ca8aa5a772efd69043d0a745172d92bee027caa7565c7f774a2f44b91207/schema-0.7.5-py2.py3-none-any.whl#sha256=f3ffdeeada09ec34bf40d7d79996d9f7175db93b7a5065de0faa7f41083c1e6c
# Best match: schema 0.7.5
# Processing schema-0.7.5-py2.py3-none-any.whl
# Installing schema-0.7.5-py2.py3-none-any.whl to /usr/local/lib/python3.10/dist-packages
# Adding schema 0.7.5 to easy-install.pth file
#
# Installed /usr/local/lib/python3.10/dist-packages/schema-0.7.5-py3.10.egg
# Searching for responses
# Reading https://pypi.org/simple/responses/
# Downloading https://files.pythonhosted.org/packages/3b/70/09ab7d1f559f045513cc5456d33a55a1896914bdcf6e8508070b679d20c5/responses-0.24.1-py3-none-any.whl#sha256=a2b43f4c08bfb9c9bd242568328c65a34b318741d3fab884ac843c5ceeb543f9
# Best match: responses 0.24.1
# Processing responses-0.24.1-py3-none-any.whl
# Installing responses-0.24.1-py3-none-any.whl to /usr/local/lib/python3.10/dist-packages
# Adding responses 0.24.1 to easy-install.pth file
#
# Installed /usr/local/lib/python3.10/dist-packages/responses-0.24.1-py3.10.egg
# Searching for PythonWebHDFS
# Reading https://pypi.org/simple/PythonWebHDFS/
# Downloading https://files.pythonhosted.org/packages/65/65/231feee80b3a5e0826e2e0d6c7921bb916f268b5cc824bdd04c4be13d9d3/PythonWebHDFS-0.2.3-py3-none-any.whl#sha256=6d4884ca16fa03f9774a37162be02b4c336447ea3e311cba1e9d55ae052df095
# Best match: PythonWebHDFS 0.2.3
# Processing PythonWebHDFS-0.2.3-py3-none-any.whl
# Installing PythonWebHDFS-0.2.3-py3-none-any.whl to /usr/local/lib/python3.10/dist-packages
# Adding PythonWebHDFS 0.2.3 to easy-install.pth file
#
# Installed /usr/local/lib/python3.10/dist-packages/PythonWebHDFS-0.2.3-py3.10.egg
# Searching for nvidia-ml-py
# Reading https://pypi.org/simple/nvidia-ml-py/
# Downloading https://files.pythonhosted.org/packages/a8/10/35b88b64d76aac88ae6b39208827ac0e2a4a2d78f3f2159882efefcad7fd/nvidia_ml_py-12.535.133-py3-none-any.whl#sha256=91d808d3f246d30bead2a0a2540b74b9e9fc584a9c3f1f55abfc2940c4e44fd2
# Best match: nvidia-ml-py 12.535.133
# Processing nvidia_ml_py-12.535.133-py3-none-any.whl
# Installing nvidia_ml_py-12.535.133-py3-none-any.whl to /usr/local/lib/python3.10/dist-packages
# Adding nvidia-ml-py 12.535.133 to easy-install.pth file
#
# Installed /usr/local/lib/python3.10/dist-packages/nvidia_ml_py-12.535.133-py3.10.egg
# Searching for json-tricks>=3.15.5
# Reading https://pypi.org/simple/json-tricks/
# Downloading https://files.pythonhosted.org/packages/ae/fd/e3edcf827e7f9c17c5ea1a192841dcfb1dd575a7518c25c5cadd921625b1/json_tricks-3.17.3-py2.py3-none-any.whl#sha256=8ba11cb66a09532945c05c7374a72b857dfc3870b2d145125edd508f4027dff9
# Best match: json-tricks 3.17.3
# Processing json_tricks-3.17.3-py2.py3-none-any.whl
# Installing json_tricks-3.17.3-py2.py3-none-any.whl to /usr/local/lib/python3.10/dist-packages
# Adding json-tricks 3.17.3 to easy-install.pth file
#
# Installed /usr/local/lib/python3.10/dist-packages/json_tricks-3.17.3-py3.10.egg
# Searching for filelock<3.12
# Reading https://pypi.org/simple/filelock/
# Downloading https://files.pythonhosted.org/packages/9e/6b/fdcd53aeee771a868c4187f0955116894a2b1e82d73fb5990c2ef63afc18/filelock-3.11.0-py3-none-any.whl#sha256=f08a52314748335c6460fc8fe40cd5638b85001225db78c2aa01c8c0db83b318
# Best match: filelock 3.11.0
# Processing filelock-3.11.0-py3-none-any.whl
# Installing filelock-3.11.0-py3-none-any.whl to /usr/local/lib/python3.10/dist-packages
# Adding filelock 3.11.0 to easy-install.pth file
#
# Installed /usr/local/lib/python3.10/dist-packages/filelock-3.11.0-py3.10.egg
# Searching for colorama
# Reading https://pypi.org/simple/colorama/
# Downloading https://files.pythonhosted.org/packages/d1/d6/3965ed04c63042e047cb6a3e6ed1a63a35087b6a609aa3a15ed8ac56c221/colorama-0.4.6-py2.py3-none-any.whl#sha256=4f1d9991f5acc0ca119f9d443620b77f9d6b33703e51011c16baf57afb285fc6
# Best match: colorama 0.4.6
# Processing colorama-0.4.6-py2.py3-none-any.whl
# Installing colorama-0.4.6-py2.py3-none-any.whl to /usr/local/lib/python3.10/dist-packages
# Adding colorama 0.4.6 to easy-install.pth file
#
# Installed /usr/local/lib/python3.10/dist-packages/colorama-0.4.6-py3.10.egg
# Searching for astor
# Reading https://pypi.org/simple/astor/
# Downloading https://files.pythonhosted.org/packages/c3/88/97eef84f48fa04fbd6750e62dcceafba6c63c81b7ac1420856c8dcc0a3f9/astor-0.8.1-py2.py3-none-any.whl#sha256=070a54e890cefb5b3739d19f30f5a5ec840ffc9c50ffa7d23cc9fc1a38ebbfc5
# Best match: astor 0.8.1
# Processing astor-0.8.1-py2.py3-none-any.whl
# Installing astor-0.8.1-py2.py3-none-any.whl to /usr/local/lib/python3.10/dist-packages
# Adding astor 0.8.1 to easy-install.pth file
#
# Installed /usr/local/lib/python3.10/dist-packages/astor-0.8.1-py3.10.egg
# Searching for iopath>=0.1.7
# Reading https://pypi.org/simple/iopath/
# Downloading https://files.pythonhosted.org/packages/72/73/b3d451dfc523756cf177d3ebb0af76dc7751b341c60e2a21871be400ae29/iopath-0.1.10.tar.gz#sha256=3311c16a4d9137223e20f141655759933e1eda24f8bff166af834af3c645ef01
# Best match: iopath 0.1.10
# Processing iopath-0.1.10.tar.gz
# Writing /tmp/easy_install-6vgivzm8/iopath-0.1.10/setup.cfg
# Running iopath-0.1.10/setup.py -q bdist_egg --dist-dir /tmp/easy_install-6vgivzm8/iopath-0.1.10/egg-dist-tmp-q05axhhq
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer, pypa/build or
#         other standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# zip_safe flag not set; analyzing archive contents...
# Adding iopath 0.1.10 to easy-install.pth file
#
# Installed /usr/local/lib/python3.10/dist-packages/iopath-0.1.10-py3.10.egg
# Searching for yacs>=0.1.6
# Reading https://pypi.org/simple/yacs/
# Downloading https://files.pythonhosted.org/packages/38/4f/fe9a4d472aa867878ce3bb7efb16654c5d63672b86dc0e6e953a67018433/yacs-0.1.8-py3-none-any.whl#sha256=99f893e30497a4b66842821bac316386f7bd5c4f47ad35c9073ef089aa33af32
# Best match: yacs 0.1.8
# Processing yacs-0.1.8-py3-none-any.whl
# Installing yacs-0.1.8-py3-none-any.whl to /usr/local/lib/python3.10/dist-packages
# Adding yacs 0.1.8 to easy-install.pth file
#
# Installed /usr/local/lib/python3.10/dist-packages/yacs-0.1.8-py3.10.egg
# Searching for simplejson
# Reading https://pypi.org/simple/simplejson/
# Downloading https://files.pythonhosted.org/packages/cb/b6/ed513a0adc3e2c9654864ffb68266dcab5720d5653428d690e7e4fb32a6c/simplejson-3.19.2-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl#sha256=18955c1da6fc39d957adfa346f75226246b6569e096ac9e40f67d102278c3bcb
# Best match: simplejson 3.19.2
# Processing simplejson-3.19.2-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# Installing simplejson-3.19.2-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl to /usr/local/lib/python3.10/dist-packages
# Adding simplejson 3.19.2 to easy-install.pth file
#
# Installed /usr/local/lib/python3.10/dist-packages/simplejson-3.19.2-py3.10-linux-x86_64.egg
# Searching for portalocker
# Reading https://pypi.org/simple/portalocker/
# Downloading https://files.pythonhosted.org/packages/17/9e/87671efcca80ba6203811540ed1f9c0462c1609d2281d7b7f53cef05da3d/portalocker-2.8.2-py3-none-any.whl#sha256=cfb86acc09b9aa7c3b43594e19be1345b9d16af3feb08bf92f23d4dce513a28e
# Best match: portalocker 2.8.2
# Processing portalocker-2.8.2-py3-none-any.whl
# Installing portalocker-2.8.2-py3-none-any.whl to /usr/local/lib/python3.10/dist-packages
# Adding portalocker 2.8.2 to easy-install.pth file
#
# Installed /usr/local/lib/python3.10/dist-packages/portalocker-2.8.2-py3.10.egg
# Searching for tqdm==4.66.1
# Best match: tqdm 4.66.1
# Adding tqdm 4.66.1 to easy-install.pth file
# Installing tqdm script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for scikit-learn==1.2.2
# Best match: scikit-learn 1.2.2
# Adding scikit-learn 1.2.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for six==1.16.0
# Best match: six 1.16.0
# Adding six 1.16.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for scikit-image==0.19.3
# Best match: scikit-image 0.19.3
# Adding scikit-image 0.19.3 to easy-install.pth file
# Installing skivi script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for pandas==1.5.3
# Best match: pandas 1.5.3
# Adding pandas 1.5.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for packaging==23.2
# Best match: packaging 23.2
# Adding packaging 23.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for opencv-python==4.8.0.76
# Best match: opencv-python 4.8.0.76
# Adding opencv-python 4.8.0.76 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for numpy==1.23.5
# Best match: numpy 1.23.5
# Adding numpy 1.23.5 to easy-install.pth file
# Installing f2py script to /usr/local/bin
# Installing f2py3 script to /usr/local/bin
# Installing f2py3.10 script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for matplotlib==3.7.1
# Best match: matplotlib 3.7.1
# Adding matplotlib 3.7.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for future==0.18.3
# Best match: future 0.18.3
# Adding future 0.18.3 to easy-install.pth file
# Installing futurize script to /usr/local/bin
# Installing pasteurize script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for dask==2023.8.1
# Best match: dask 2023.8.1
# Adding dask 2023.8.1 to easy-install.pth file
# Installing dask script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for setuptools==67.7.2
# Best match: setuptools 67.7.2
# Adding setuptools 67.7.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for huggingface-hub==0.19.4
# Best match: huggingface-hub 0.19.4
# Adding huggingface-hub 0.19.4 to easy-install.pth file
# Installing huggingface-cli script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for PyYAML==6.0.1
# Best match: PyYAML 6.0.1
# Adding PyYAML 6.0.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for torchvision==0.16.0+cu118
# Best match: torchvision 0.16.0+cu118
# Adding torchvision 0.16.0+cu118 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for torch==2.1.0+cu118
# Best match: torch 2.1.0+cu118
# Adding torch 2.1.0+cu118 to easy-install.pth file
# Installing convert-caffe2-to-onnx script to /usr/local/bin
# Installing convert-onnx-to-caffe2 script to /usr/local/bin
# Installing torchrun script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for threadpoolctl==3.2.0
# Best match: threadpoolctl 3.2.0
# Adding threadpoolctl 3.2.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for joblib==1.3.2
# Best match: joblib 1.3.2
# Adding joblib 1.3.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for scipy==1.11.3
# Best match: scipy 1.11.3
# Adding scipy 1.11.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for PyWavelets==1.4.1
# Best match: PyWavelets 1.4.1
# Adding PyWavelets 1.4.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for tifffile==2023.9.26
# Best match: tifffile 2023.9.26
# Adding tifffile 2023.9.26 to easy-install.pth file
# Installing lsm2bin script to /usr/local/bin
# Installing tiff2fsspec script to /usr/local/bin
# Installing tiffcomment script to /usr/local/bin
# Installing tifffile script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for imageio==2.31.6
# Best match: imageio 2.31.6
# Adding imageio 2.31.6 to easy-install.pth file
# Installing imageio_download_bin script to /usr/local/bin
# Installing imageio_remove_bin script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for Pillow==9.4.0
# Best match: Pillow 9.4.0
# Adding Pillow 9.4.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for networkx==3.2.1
# Best match: networkx 3.2.1
# Adding networkx 3.2.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for pytz==2023.3.post1
# Best match: pytz 2023.3.post1
# Adding pytz 2023.3.post1 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for python-dateutil==2.8.2
# Best match: python-dateutil 2.8.2
# Adding python-dateutil 2.8.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for certifi==2023.7.22
# Best match: certifi 2023.7.22
# Adding certifi 2023.7.22 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for requests==2.31.0
# Best match: requests 2.31.0
# Adding requests 2.31.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for psutil==5.9.5
# Best match: psutil 5.9.5
# Adding psutil 5.9.5 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for prettytable==3.9.0
# Best match: prettytable 3.9.0
# Adding prettytable 3.9.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for cloudpickle==2.2.1
# Best match: cloudpickle 2.2.1
# Adding cloudpickle 2.2.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for pyparsing==3.1.1
# Best match: pyparsing 3.1.1
# Adding pyparsing 3.1.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for kiwisolver==1.4.5
# Best match: kiwisolver 1.4.5
# Adding kiwisolver 1.4.5 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for fonttools==4.44.3
# Best match: fonttools 4.44.3
# Adding fonttools 4.44.3 to easy-install.pth file
# Installing fonttools script to /usr/local/bin
# Installing pyftmerge script to /usr/local/bin
# Installing pyftsubset script to /usr/local/bin
# Installing ttx script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for cycler==0.12.1
# Best match: cycler 0.12.1
# Adding cycler 0.12.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for contourpy==1.2.0
# Best match: contourpy 1.2.0
# Adding contourpy 1.2.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for h5py==3.9.0
# Best match: h5py 3.9.0
# Adding h5py 3.9.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for tabulate==0.9.0
# Best match: tabulate 0.9.0
# Adding tabulate 0.9.0 to easy-install.pth file
# Installing tabulate script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for termcolor==2.3.0
# Best match: termcolor 2.3.0
# Adding termcolor 2.3.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for importlib-metadata==6.8.0
# Best match: importlib-metadata 6.8.0
# Adding importlib-metadata 6.8.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for toolz==0.12.0
# Best match: toolz 0.12.0
# Adding toolz 0.12.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for partd==1.4.1
# Best match: partd 1.4.1
# Adding partd 1.4.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for fsspec==2023.6.0
# Best match: fsspec 2023.6.0
# Adding fsspec 2023.6.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for click==8.1.7
# Best match: click 8.1.7
# Adding click 8.1.7 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for triton==2.1.0
# Best match: triton 2.1.0
# Adding triton 2.1.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for Jinja2==3.1.2
# Best match: Jinja2 3.1.2
# Adding Jinja2 3.1.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for sympy==1.12
# Best match: sympy 1.12
# Adding sympy 1.12 to easy-install.pth file
# Installing isympy script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for contextlib2==21.6.0
# Best match: contextlib2 21.6.0
# Adding contextlib2 21.6.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for urllib3==2.0.7
# Best match: urllib3 2.0.7
# Adding urllib3 2.0.7 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for idna==3.4
# Best match: idna 3.4
# Adding idna 3.4 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for charset-normalizer==3.3.2
# Best match: charset-normalizer 3.3.2
# Adding charset-normalizer 3.3.2 to easy-install.pth file
# Installing normalizer script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for wcwidth==0.2.10
# Best match: wcwidth 0.2.10
# Adding wcwidth 0.2.10 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for zipp==3.17.0
# Best match: zipp 3.17.0
# Adding zipp 3.17.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for locket==1.0.0
# Best match: locket 1.0.0
# Adding locket 1.0.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for MarkupSafe==2.1.3
# Best match: MarkupSafe 2.1.3
# Adding MarkupSafe 2.1.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for mpmath==1.3.0
# Best match: mpmath 1.3.0
# Adding mpmath 1.3.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Finished processing dependencies for OpenSTL==0.3.0

# %% [markdown]
# ## 1. Process your data
#
# Assume you possess a collection of videos and have already sorted them into the `train/`, `val/`, and `test/` directories. The subsequent step involves transforming these videos into a `.pkl` file for further manipulations.
#
# The existing file hierarchy is as follows:
#
# - custom_usage.ipynb
# - train
#   - train_example1.avi
#   - train_example2.avi
# - val
#   - val_example1.avi
#   - val_example2.avi
# - test
#   - test_example.avi
#
# It's crucial to note that the above example represents a simplified scenario where we've used `.avi` videos for illustrative purposes. However, in a real-world application, you are free to employ videos in various other formats.
#
# We utilize several videos from the KTH dataset as examples. Although the original KTH dataset consists of single-channel grayscale videos, we save them as three-channel RGB videos to accommodate a broader range of use cases.

# %% [markdown]
# ### 1.1 Save the dataset
#
# Here, we default to uniformly sampling several frames from the given video data. The number of observed frames and future frames are two hyperparameters (`pre_seq_length`, `aft_seq_length`) that are set in advance. You can also choose to sample the video in other ways and save the data.

# %% [markdown]
# #### hyperparameters
#
# `pre_seq_length`: the number of given frames
#
# `aft_seq_length`: the number of frames to predict

# %%
pre_seq_length = 10
aft_seq_length = 20

# %%
import cv2
import numpy as np
import os

def sample_frames(video_path, num_frames=20):
    # read the video
    video = cv2.VideoCapture(video_path)
    total_frames = int(video.get(cv2.CAP_PROP_FRAME_COUNT))
    # uniformly sample frames from the video
    frame_idxs = np.linspace(0, total_frames-1, num_frames, dtype=int)
    frames = []
    for idx in frame_idxs:
        video.set(cv2.CAP_PROP_POS_FRAMES, idx)
        _, frame = video.read()
        # frame = cv2.resize(frame, (height, width))
        frames.append(frame)
    video.release()
    return np.stack(frames)

def process_folder(folder_path, pre_slen=10, aft_slen=10, suffix='.avi'):
    # get all the videos in this folder
    videos = []
    files = os.listdir(folder_path)
    for file in files:
        video_path = os.path.join(folder_path, file)
        if os.path.isfile(video_path) and file.endswith(suffix):
            video = sample_frames(video_path, pre_slen + aft_slen)
            videos.append(video)
    # stack video frames from each folder
    data = np.stack(videos).transpose(0, 1, 4, 2, 3)

    # if the data is in [0, 255], rescale it into [0, 1]
    if data.max() > 1.0:
        data = data.astype(np.float32) / 255.0

    return data[:, :pre_slen], data[:, pre_slen:]

# %%
import pickle

dataset = {}
folders = ['train', 'val', 'test']
for folder in folders:
    data_x, data_y = process_folder('examples/' + folder, pre_slen=pre_seq_length, aft_slen=aft_seq_length, suffix='.avi')
    dataset['X_' + folder], dataset['Y_' + folder] = data_x, data_y

# save as a pkl file
with open('dataset.pkl', 'wb') as f:
    pickle.dump(dataset, f)

# %% [markdown]
# ### 1.2 Load the dataset and visualize an example

# %%
import pickle

# load the dataset
with open('dataset.pkl', 'rb') as f:
    dataset = pickle.load(f)

train_x, train_y = dataset['X_train'], dataset['Y_train']
print(train_x.shape)
# the shape is B x T x C x H x W
# B: the number of samples
# T: the number of frames in each sample
# C, H, W: the height, width, channel of each frame
# Out:
# (2, 10, 3, 32, 32)

# %%
from openstl.utils import show_video_line

# show the given frames from an example
example_idx = 0
show_video_line(train_x[example_idx], ncols=pre_seq_length, vmax=0.6, cbar=False, out_path=None, format='png', use_rgb=True)

# %%
# show the future frames from an example
example_idx = 0
show_video_line(train_y[example_idx], ncols=aft_seq_length, vmax=0.6, cbar=False, out_path=None, format='png', use_rgb=True)

# %% [markdown]
# ## 2. Utilize cumtom data

# %% [markdown]
# ### 2.1 Define the dataset
#
# We first define the `CustomDataset` to use the provided dataset.
#
# For real video prediction, to facilitate model optimization, we strongly recommend users to use frames represented as `float32` with values in the range of $[0, 1]$, rather than frames represented as `uint8` with values in the range of $[0, 255]$. For other types of data, we also provide the option to `normalize` in the `CustomDataset`.

# %%
import torch
from torch.utils.data import Dataset


class CustomDataset(Dataset):
    def __init__(self, X, Y, normalize=False):
        super(CustomDataset, self).__init__()
        self.X = X
        self.Y = Y
        self.mean = None
        self.std = None

        if normalize:
            # get the mean/std values along the channel dimension
            mean = data.mean(axis=(0, 1, 2, 3)).reshape(1, 1, -1, 1, 1)
            std = data.std(axis=(0, 1, 2, 3)).reshape(1, 1, -1, 1, 1)
            data = (data - mean) / std
            self.mean = mean
            self.std = std

    def __len__(self):
        return self.X.shape[0]

    def __getitem__(self, index):
        data = torch.tensor(self.X[index]).float()
        labels = torch.tensor(self.Y[index]).float()
        return data, labels

# %% [markdown]
# ### 2.2 Get the dataloaders
#
# Now we can get the dataloaders by using the collected dataset and the defined `CustomDataset`.

# %% [markdown]
# #### hyperparameters
#
# `batch_size`: the size of a batch

# %%
batch_size = 1

# %%
X_train, X_val, X_test, Y_train, Y_val, Y_test = dataset['X_train'], dataset[
    'X_val'], dataset['X_test'], dataset['Y_train'], dataset['Y_val'], dataset['Y_test']

train_set = CustomDataset(X=X_train, Y=Y_train)
val_set = CustomDataset(X=X_val, Y=Y_val)
test_set = CustomDataset(X=X_test, Y=Y_test)

# %%
dataloader_train = torch.utils.data.DataLoader(
    train_set, batch_size=batch_size, shuffle=True, pin_memory=True)
dataloader_val = torch.utils.data.DataLoader(
    val_set, batch_size=batch_size, shuffle=True, pin_memory=True)
dataloader_test = torch.utils.data.DataLoader(
    test_set, batch_size=batch_size, shuffle=True, pin_memory=True)

# %% [markdown]
# ## 3. Train and evaluate

# %% [markdown]
# ### 3.1 Define the custom configs
#
# We first define the training configuration, which includes several important hyperparameters for training.
#
# Here, we set `epoch = 3` as an example for simple training. The actual value of epoch in your project depends on the complexity of your dataset. Generally, a good starting point is `epoch = 100`.
#
# Next, we define the model configuration to customize a spatio-temporal predictive learning model. For MetaVP models, the key hyperparameters are: `N_S`, `N_T`, `hid_S`, `hid_T`, and `model_type`. Users have the option to either use a config file or directly set these hyperparameters.
#
# If a config file is preferred, the user can simply include a `config_file` key with the path to the config file in the `custom_model_config` below. Otherwise, the user can directly specify these hyperparameters in the `custom_model_config`.

# %%
custom_training_config = {
    'pre_seq_length': pre_seq_length,
    'aft_seq_length': aft_seq_length,
    'total_length': pre_seq_length + aft_seq_length,
    'batch_size': batch_size,
    'val_batch_size': batch_size,
    'epoch': 3,
    'lr': 0.001,
    'metrics': ['mse', 'mae'],

    'ex_name': 'custom_exp',
    'dataname': 'custom',
    'in_shape': [10, 3, 32, 32],
}

custom_model_config = {
    # For MetaVP models, the most important hyperparameters are:
    # N_S, N_T, hid_S, hid_T, model_type
    'method': 'SimVP',
    # Users can either using a config file or directly set these hyperparameters
    # 'config_file': 'configs/custom/example_model.py',

    # Here, we directly set these parameters
    'model_type': 'gSTA',
    'N_S': 4,
    'N_T': 8,
    'hid_S': 64,
    'hid_T': 256
}

# %% [markdown]
# ### 3.2 Setup the experiment
#
# We retrieve the default hyperparameters by utilizing `create_parser` and update those hyperparameters that are defined in `custom_training_config` and `custom_model_config`.
#
# By utilizing `BaseExperiment`, we ensure that everything is prepared, including dataloader setup and model initialization.

# %%
from openstl.api import BaseExperiment
from openstl.utils import create_parser

args = create_parser().parse_args([])
config = args.__dict__

# update the training config
config.update(custom_training_config)
# update the model config
config.update(custom_model_config)

exp = BaseExperiment(args, dataloaders=(dataloader_train, dataloader_val, dataloader_test))
# Out:
# Use non-distributed mode with GPU: cuda:0
# Environment info:
# ------------------------------------------------------------
# sys.platform: linux
# Python: 3.10.12 (main, Jun  7 2023, 12:45:35) [GCC 9.4.0]
# CUDA available: True
# CUDA_HOME: /usr/local/cuda
# NVCC: Build cuda_11.8.r11.8/compiler.31833905_0
# GPU 0: Tesla T4
# GCC: gcc (Ubuntu 9.4.0-1ubuntu1~20.04.1) 9.4.0
# PyTorch: 2.0.1+cu118
# PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2022.2-Product Build 20220804 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.7.3 (Git Hash 6dbeffbae1f23cbbeae17adb7b5b13f1f37c080e)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.8
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_90,code=sm_90
#   - CuDNN 8.7
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.8, CUDNN_VERSION=8.7.0, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -D_GLIBCXX_USE_CXX11_ABI=0 -fabi-version=11 -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Werror=bool-operation -Wnarrowing -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wunused-local-typedefs -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_DISABLE_GPU_ASSERTS=ON, TORCH_VERSION=2.0.1, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=1, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
# TorchVision: 0.15.2+cu118
# OpenCV: 4.7.0
# openstl: 0.3.0
# ------------------------------------------------------------
#
#
# device: 	cuda
# dist: 	False
# display_step: 	10
# res_dir: 	work_dirs
# ex_name: 	custom_exp
# use_gpu: 	True
# fp16: 	False
# torchscript: 	False
# seed: 	42
# diff_seed: 	False
# fps: 	False
# empty_cache: 	True
# find_unused_parameters: 	False
# broadcast_buffers: 	True
# resume_from: 	None
# auto_resume: 	False
# test: 	False
# deterministic: 	False
# launcher: 	none
# local_rank: 	0
# port: 	29500
# batch_size: 	1
# val_batch_size: 	1
# num_workers: 	4
# data_root: 	./data
# dataname: 	custom
# pre_seq_length: 	10
# aft_seq_length: 	20
# total_length: 	30
# use_augment: 	False
# use_prefetcher: 	False
# drop_last: 	False
# method: 	simvp
# config_file: 	configs/mmnist/simvp/SimVP_gSTA.py
# model_type: 	gSTA
# drop: 	0.0
# drop_path: 	0.0
# overwrite: 	False
# epoch: 	3
# log_step: 	1
# opt: 	adam
# opt_eps: 	None
# opt_betas: 	None
# momentum: 	0.9
# weight_decay: 	0.0
# clip_grad: 	None
# clip_mode: 	norm
# sched: 	onecycle
# lr: 	0.001
# lr_k_decay: 	1.0
# warmup_lr: 	1e-05
# min_lr: 	1e-06
# final_div_factor: 	10000.0
# warmup_epoch: 	0
# decay_epoch: 	100
# decay_rate: 	0.1
# filter_bias_and_bn: 	False
# metrics: 	['mse', 'mae']
# in_shape: 	[10, 3, 32, 32]
# N_S: 	4
# N_T: 	8
# hid_S: 	64
# hid_T: 	256
# Model info:
# SimVP_Model(
#   (enc): Encoder(
#     (enc): Sequential(
#       (0): ConvSC(
#         (conv): BasicConv2d(
#           (conv): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (norm): GroupNorm(2, 64, eps=1e-05, affine=True)
#           (act): SiLU()
#         )
#       )
#       (1): ConvSC(
#         (conv): BasicConv2d(
#           (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (norm): GroupNorm(2, 64, eps=1e-05, affine=True)
#           (act): SiLU()
#         )
#       )
#       (2): ConvSC(
#         (conv): BasicConv2d(
#           (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (norm): GroupNorm(2, 64, eps=1e-05, affine=True)
#           (act): SiLU()
#         )
#       )
#       (3): ConvSC(
#         (conv): BasicConv2d(
#           (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (norm): GroupNorm(2, 64, eps=1e-05, affine=True)
#           (act): SiLU()
#         )
#       )
#     )
#   )
#   (dec): Decoder(
#     (dec): Sequential(
#       (0): ConvSC(
#         (conv): BasicConv2d(
#           (conv): Sequential(
#             (0): Conv2d(64, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (1): PixelShuffle(upscale_factor=2)
#           )
#           (norm): GroupNorm(2, 64, eps=1e-05, affine=True)
#           (act): SiLU()
#         )
#       )
#       (1): ConvSC(
#         (conv): BasicConv2d(
#           (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (norm): GroupNorm(2, 64, eps=1e-05, affine=True)
#           (act): SiLU()
#         )
#       )
#       (2): ConvSC(
#         (conv): BasicConv2d(
#           (conv): Sequential(
#             (0): Conv2d(64, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (1): PixelShuffle(upscale_factor=2)
#           )
#           (norm): GroupNorm(2, 64, eps=1e-05, affine=True)
#           (act): SiLU()
#         )
#       )
#       (3): ConvSC(
#         (conv): BasicConv2d(
#           (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (norm): GroupNorm(2, 64, eps=1e-05, affine=True)
#           (act): SiLU()
#         )
#       )
#     )
#     (readout): Conv2d(64, 3, kernel_size=(1, 1), stride=(1, 1))
#   )
#   (hid): MidMetaNet(
#     (enc): Sequential(
#       (0): MetaBlock(
#         (block): GASubBlock(
#           (norm1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (attn): SpatialAttention(
#             (proj_1): Conv2d(640, 640, kernel_size=(1, 1), stride=(1, 1))
#             (activation): GELU(approximate='none')
#             (spatial_gating_unit): AttentionModule(
#               (conv0): Conv2d(640, 640, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=640)
#               (conv_spatial): Conv2d(640, 640, kernel_size=(7, 7), stride=(1, 1), padding=(9, 9), dilation=(3, 3), groups=640)
#               (conv1): Conv2d(640, 1280, kernel_size=(1, 1), stride=(1, 1))
#             )
#             (proj_2): Conv2d(640, 640, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (drop_path): DropPath(drop_prob=0.010)
#           (norm2): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): MixMlp(
#             (fc1): Conv2d(640, 5120, kernel_size=(1, 1), stride=(1, 1))
#             (dwconv): DWConv(
#               (dwconv): Conv2d(5120, 5120, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=5120)
#             )
#             (act): GELU(approximate='none')
#             (fc2): Conv2d(5120, 640, kernel_size=(1, 1), stride=(1, 1))
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (reduction): Conv2d(640, 256, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (1): MetaBlock(
#         (block): GASubBlock(
#           (norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (attn): SpatialAttention(
#             (proj_1): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#             (activation): GELU(approximate='none')
#             (spatial_gating_unit): AttentionModule(
#               (conv0): Conv2d(256, 256, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=256)
#               (conv_spatial): Conv2d(256, 256, kernel_size=(7, 7), stride=(1, 1), padding=(9, 9), dilation=(3, 3), groups=256)
#               (conv1): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1))
#             )
#             (proj_2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (drop_path): DropPath(drop_prob=0.009)
#           (norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): MixMlp(
#             (fc1): Conv2d(256, 2048, kernel_size=(1, 1), stride=(1, 1))
#             (dwconv): DWConv(
#               (dwconv): Conv2d(2048, 2048, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=2048)
#             )
#             (act): GELU(approximate='none')
#             (fc2): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#       )
#       (2): MetaBlock(
#         (block): GASubBlock(
#           (norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (attn): SpatialAttention(
#             (proj_1): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#             (activation): GELU(approximate='none')
#             (spatial_gating_unit): AttentionModule(
#               (conv0): Conv2d(256, 256, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=256)
#               (conv_spatial): Conv2d(256, 256, kernel_size=(7, 7), stride=(1, 1), padding=(9, 9), dilation=(3, 3), groups=256)
#               (conv1): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1))
#             )
#             (proj_2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (drop_path): DropPath(drop_prob=0.007)
#           (norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): MixMlp(
#             (fc1): Conv2d(256, 2048, kernel_size=(1, 1), stride=(1, 1))
#             (dwconv): DWConv(
#               (dwconv): Conv2d(2048, 2048, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=2048)
#             )
#             (act): GELU(approximate='none')
#             (fc2): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#       )
#       (3): MetaBlock(
#         (block): GASubBlock(
#           (norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (attn): SpatialAttention(
#             (proj_1): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#             (activation): GELU(approximate='none')
#             (spatial_gating_unit): AttentionModule(
#               (conv0): Conv2d(256, 256, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=256)
#               (conv_spatial): Conv2d(256, 256, kernel_size=(7, 7), stride=(1, 1), padding=(9, 9), dilation=(3, 3), groups=256)
#               (conv1): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1))
#             )
#             (proj_2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (drop_path): DropPath(drop_prob=0.006)
#           (norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): MixMlp(
#             (fc1): Conv2d(256, 2048, kernel_size=(1, 1), stride=(1, 1))
#             (dwconv): DWConv(
#               (dwconv): Conv2d(2048, 2048, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=2048)
#             )
#             (act): GELU(approximate='none')
#             (fc2): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#       )
#       (4): MetaBlock(
#         (block): GASubBlock(
#           (norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (attn): SpatialAttention(
#             (proj_1): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#             (activation): GELU(approximate='none')
#             (spatial_gating_unit): AttentionModule(
#               (conv0): Conv2d(256, 256, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=256)
#               (conv_spatial): Conv2d(256, 256, kernel_size=(7, 7), stride=(1, 1), padding=(9, 9), dilation=(3, 3), groups=256)
#               (conv1): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1))
#             )
#             (proj_2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (drop_path): DropPath(drop_prob=0.004)
#           (norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): MixMlp(
#             (fc1): Conv2d(256, 2048, kernel_size=(1, 1), stride=(1, 1))
#             (dwconv): DWConv(
#               (dwconv): Conv2d(2048, 2048, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=2048)
#             )
#             (act): GELU(approximate='none')
#             (fc2): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#       )
#       (5): MetaBlock(
#         (block): GASubBlock(
#           (norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (attn): SpatialAttention(
#             (proj_1): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#             (activation): GELU(approximate='none')
#             (spatial_gating_unit): AttentionModule(
#               (conv0): Conv2d(256, 256, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=256)
#               (conv_spatial): Conv2d(256, 256, kernel_size=(7, 7), stride=(1, 1), padding=(9, 9), dilation=(3, 3), groups=256)
#               (conv1): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1))
#             )
#             (proj_2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (drop_path): DropPath(drop_prob=0.003)
#           (norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): MixMlp(
#             (fc1): Conv2d(256, 2048, kernel_size=(1, 1), stride=(1, 1))
#             (dwconv): DWConv(
#               (dwconv): Conv2d(2048, 2048, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=2048)
#             )
#             (act): GELU(approximate='none')
#             (fc2): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#       )
#       (6): MetaBlock(
#         (block): GASubBlock(
#           (norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (attn): SpatialAttention(
#             (proj_1): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#             (activation): GELU(approximate='none')
#             (spatial_gating_unit): AttentionModule(
#               (conv0): Conv2d(256, 256, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=256)
#               (conv_spatial): Conv2d(256, 256, kernel_size=(7, 7), stride=(1, 1), padding=(9, 9), dilation=(3, 3), groups=256)
#               (conv1): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1))
#             )
#             (proj_2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (drop_path): DropPath(drop_prob=0.001)
#           (norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): MixMlp(
#             (fc1): Conv2d(256, 2048, kernel_size=(1, 1), stride=(1, 1))
#             (dwconv): DWConv(
#               (dwconv): Conv2d(2048, 2048, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=2048)
#             )
#             (act): GELU(approximate='none')
#             (fc2): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#       )
#       (7): MetaBlock(
#         (block): GASubBlock(
#           (norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (attn): SpatialAttention(
#             (proj_1): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#             (activation): GELU(approximate='none')
#             (spatial_gating_unit): AttentionModule(
#               (conv0): Conv2d(256, 256, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=256)
#               (conv_spatial): Conv2d(256, 256, kernel_size=(7, 7), stride=(1, 1), padding=(9, 9), dilation=(3, 3), groups=256)
#               (conv1): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1))
#             )
#             (proj_2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (drop_path): Identity()
#           (norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): MixMlp(
#             (fc1): Conv2d(256, 2048, kernel_size=(1, 1), stride=(1, 1))
#             (dwconv): DWConv(
#               (dwconv): Conv2d(2048, 2048, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=2048)
#             )
#             (act): GELU(approximate='none')
#             (fc2): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (reduction): Conv2d(256, 640, kernel_size=(1, 1), stride=(1, 1))
#       )
#     )
#   )
# )
# | module                           | #parameters or shape   | #flops     |
# |:---------------------------------|:-----------------------|:-----------|
# | model                            | 18.604M                | 2.345G     |
# |  enc.enc                         |  0.113M                |  0.235G    |
# |   enc.enc.0.conv                 |   1.92K                |   20.972M  |
# |    enc.enc.0.conv.conv           |    1.792K              |    17.695M |
# |    enc.enc.0.conv.norm           |    0.128K              |    3.277M  |
# |   enc.enc.1.conv                 |   37.056K              |   95.191M  |
# |    enc.enc.1.conv.conv           |    36.928K             |    94.372M |
# |    enc.enc.1.conv.norm           |    0.128K              |    0.819M  |
# |   enc.enc.2.conv                 |   37.056K              |   95.191M  |
# |    enc.enc.2.conv.conv           |    36.928K             |    94.372M |
# |    enc.enc.2.conv.norm           |    0.128K              |    0.819M  |
# |   enc.enc.3.conv                 |   37.056K              |   23.798M  |
# |    enc.enc.3.conv.conv           |    36.928K             |    23.593M |
# |    enc.enc.3.conv.norm           |    0.128K              |    0.205M  |
# |  dec                             |  0.37M                 |  0.954G    |
# |   dec.dec                        |   0.37M                |   0.952G   |
# |    dec.dec.0.conv                |    0.148M              |    95.191M |
# |    dec.dec.1.conv                |    37.056K             |    95.191M |
# |    dec.dec.2.conv                |    0.148M              |    0.381G  |
# |    dec.dec.3.conv                |    37.056K             |    0.381G  |
# |   dec.readout                    |   0.195K               |   1.966M   |
# |    dec.readout.weight            |    (3, 64, 1, 1)       |            |
# |    dec.readout.bias              |    (3,)                |            |
# |  hid.enc                         |  18.121M               |  1.156G    |
# |   hid.enc.0                      |   8.468M               |   0.541G   |
# |    hid.enc.0.block               |    8.304M              |    0.53G   |
# |    hid.enc.0.reduction           |    0.164M              |    10.486M |
# |   hid.enc.1.block                |   1.356M               |   86.344M  |
# |    hid.enc.1.block.layer_scale_1 |    (256,)              |            |
# |    hid.enc.1.block.layer_scale_2 |    (256,)              |            |
# |    hid.enc.1.block.norm1         |    0.512K              |    32.768K |
# |    hid.enc.1.block.attn          |    0.283M              |    17.99M  |
# |    hid.enc.1.block.norm2         |    0.512K              |    32.768K |
# |    hid.enc.1.block.mlp           |    1.071M              |    68.289M |
# |   hid.enc.2.block                |   1.356M               |   86.344M  |
# |    hid.enc.2.block.layer_scale_1 |    (256,)              |            |
# |    hid.enc.2.block.layer_scale_2 |    (256,)              |            |
# |    hid.enc.2.block.norm1         |    0.512K              |    32.768K |
# |    hid.enc.2.block.attn          |    0.283M              |    17.99M  |
# |    hid.enc.2.block.norm2         |    0.512K              |    32.768K |
# |    hid.enc.2.block.mlp           |    1.071M              |    68.289M |
# |   hid.enc.3.block                |   1.356M               |   86.344M  |
# |    hid.enc.3.block.layer_scale_1 |    (256,)              |            |
# |    hid.enc.3.block.layer_scale_2 |    (256,)              |            |
# |    hid.enc.3.block.norm1         |    0.512K              |    32.768K |
# |    hid.enc.3.block.attn          |    0.283M              |    17.99M  |
# |    hid.enc.3.block.norm2         |    0.512K              |    32.768K |
# |    hid.enc.3.block.mlp           |    1.071M              |    68.289M |
# |   hid.enc.4.block                |   1.356M               |   86.344M  |
# |    hid.enc.4.block.layer_scale_1 |    (256,)              |            |
# |    hid.enc.4.block.layer_scale_2 |    (256,)              |            |
# |    hid.enc.4.block.norm1         |    0.512K              |    32.768K |
# |    hid.enc.4.block.attn          |    0.283M              |    17.99M  |
# |    hid.enc.4.block.norm2         |    0.512K              |    32.768K |
# |    hid.enc.4.block.mlp           |    1.071M              |    68.289M |
# |   hid.enc.5.block                |   1.356M               |   86.344M  |
# |    hid.enc.5.block.layer_scale_1 |    (256,)              |            |
# |    hid.enc.5.block.layer_scale_2 |    (256,)              |            |
# |    hid.enc.5.block.norm1         |    0.512K              |    32.768K |
# |    hid.enc.5.block.attn          |    0.283M              |    17.99M  |
# |    hid.enc.5.block.norm2         |    0.512K              |    32.768K |
# |    hid.enc.5.block.mlp           |    1.071M              |    68.289M |
# |   hid.enc.6.block                |   1.356M               |   86.344M  |
# |    hid.enc.6.block.layer_scale_1 |    (256,)              |            |
# |    hid.enc.6.block.layer_scale_2 |    (256,)              |            |
# |    hid.enc.6.block.norm1         |    0.512K              |    32.768K |
# |    hid.enc.6.block.attn          |    0.283M              |    17.99M  |
# |    hid.enc.6.block.norm2         |    0.512K              |    32.768K |
# |    hid.enc.6.block.mlp           |    1.071M              |    68.289M |
# |   hid.enc.7                      |   1.52M                |   96.829M  |
# |    hid.enc.7.block               |    1.356M              |    86.344M |
# |    hid.enc.7.reduction           |    0.164M              |    10.486M |
# --------------------------------------------------------------------------------

# %% [markdown]
# ### 3.3 Start training and evaluation
#
# With everything in place, we are now ready to start training and evaluation.
#
# Here we go!

# %%
print('>'*35 + ' training ' + '<'*35)
exp.train()

print('>'*35 + ' testing  ' + '<'*35)
exp.test()
# Out:
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> training <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# train loss: 0.0783 | data time: 0.0047: 100%|██████████| 2/2 [00:01<00:00,  1.61it/s]
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 2/2, 31.0 task/s, elapsed: 0s, ETA:     0sval	 mse:577.9671630859375, mae:988.0562133789062
# [2023-06-28 05:18:20] Intermediate result: 577.96716  (Index 0)
# Epoch: 1, Steps: 2 | Lr: 0.0008117 | Train Loss: 0.0925540 | Vali Loss: 0.1881404
#
# Validation loss decreased (inf --> 0.188140).  Saving model ...
# train loss: 0.0628 | data time: 0.0019: 100%|██████████| 2/2 [00:00<00:00, 14.83it/s]
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 2/2, 37.4 task/s, elapsed: 0s, ETA:     0s
# val	 mse:129.93109130859375, mae:531.420654296875
# [2023-06-28 05:18:21] Intermediate result: 129.93109  (Index 1)
# Epoch: 2, Steps: 2 | Lr: 0.0001335 | Train Loss: 0.1250532 | Vali Loss: 0.0422953
#
# Validation loss decreased (0.188140 --> 0.042295).  Saving model ...
# train loss: 0.0415 | data time: 0.0063: 100%|██████████| 2/2 [00:00<00:00, 15.47it/s]
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 2/2, 33.1 task/s, elapsed: 0s, ETA:     0sval	 mse:122.43119812011719, mae:515.7534790039062
# [2023-06-28 05:18:23] Intermediate result: 122.4312  (Index 2)
# Epoch: 3, Steps: 2 | Lr: 0.0001335 | Train Loss: 0.0425023 | Vali Loss: 0.0398539
#
# Validation loss decreased (0.042295 --> 0.039854).  Saving model ...
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> testing  <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 1/1, 27.8 task/s, elapsed: 0s, ETA:     0smse:121.0665054321289, mae:512.7760620117188
# 121.066505

# %% [markdown]
# ## Visualization
#
# By employing the `show_video_line` and `show_video_gif_multiple` functions provided by `OpenSTL`, we can visualize the input, ground truth, and predicted frames, as well as generate corresponding GIFs.

# %% [markdown]
# ### 4.1 Visualize in a line

# %%
import numpy as np
from openstl.utils import show_video_line

# show the given frames from an example
inputs = np.load('./work_dirs/custom_exp/saved/inputs.npy')
preds = np.load('./work_dirs/custom_exp/saved/preds.npy')
trues = np.load('./work_dirs/custom_exp/saved/trues.npy')

example_idx = 0
show_video_line(trues[example_idx], ncols=aft_seq_length, vmax=0.6, cbar=False, out_path=None, format='png', use_rgb=True)

# %%
example_idx = 0
show_video_line(preds[example_idx], ncols=aft_seq_length, vmax=0.6, cbar=False, out_path=None, format='png', use_rgb=True)

# %% [markdown]
# ### 4.2 Generate a GIF

# %%
from openstl.utils import show_video_gif_multiple

example_idx = 0
show_video_gif_multiple(inputs[example_idx], trues[example_idx], preds[example_idx], use_rgb=True, out_path='example.gif')
